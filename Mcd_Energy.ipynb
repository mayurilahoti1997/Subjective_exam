# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Specify the encoding as 'latin1'
df = pd.read_csv(r"C:\Users\Mohit Lahoti\OneDrive\Desktop\macd.csv", encoding='latin1')

# %%
df
# Out:
#       Menu Category            Menu Items              per serve  \
# 0       Regular Menu    McSpicyåAC Panee                   199 g
# 1       Regular Menu   Spicy Paneer Wrap                   250 g
# 2     Breakfast Menu    Double Cheese Mt                    100g
# 3     Breakfast Menu    Sausage McMuffir                    112g
# 4        McCafe Menu        FlatWhite(R)                 347.5ml
# 5        McCafe Menu            Mocha (S)               242.5 ml
# 6      Desserts Menu    Small McFlurry -o                 86.79g
# 7      Desserts Menu    Regular McFlurry                 147.38g
# 8      Gourmet Menu   American Triple Cl                    195g
# 9      Gourmet Menu     Cheese Lava Burg                   240g
# 10  Condiments Menu       BBQdipingsauce                     25g
# 11  Condiments Menu         Piri Piri Mix                     5g
#
#     Energy (kcal)   Protein(g)  Total fat  Sat Fat  Trans fat  Cholester  \
# 0          652.76        20.29      39.45    17.12       0.18      21.85
# 1          674.68        20.96      39.10    19.73       0.26      40.93
# 2          273.78         9.58      12.82     8.84       0.21      37.75
# 3          281.44        16.25      10.81     6.04       0.17      53.02
# 4          215.72        10.36      12.02     8.84       0.35      36.48
# 5          185.85         7.15       8.20     5.94       0.26      24.43
# 6          116.36         2.05       3.70     2.25       0.07       4.80
# 7          209.39         3.58       6.81     4.07       0.12       8.00
# 8          457.94        24.43      22.65    11.56       0.17      71.23
# 9          671.06        14.99      33.48    14.12       0.21      33.21
# 10          54.89         0.26       0.49     0.15       0.04       0.25
# 11          17.13         0.51       0.36     0.08       0.01       0.05
#
#     Total Carb  Total Sugar  Added sugar  Sodium (mg)
# 0        52.33         8.35         5.27      1074.58
# 1        59.27         3.50         1.08       107.46
# 2        29.00         2.59         0.75       622.95
# 3        28.62         2.38         0.75       742.60
# 4        19.08        14.41         0.00       154.98
# 5        22.59        17.57         6.08       132.84
# 6        18.69        14.49        10.80        80.73
# 7        33.42        25.35        19.23       150.90
# 8        37.45         7.64         3.84      1396.17
# 9        74.25        16.27        10.01      1153.99
# 10       12.36         7.65         2.50       113.23
# 11        2.50         0.66         0.40       414.71

# %%
df.columns
# Out:
# Index(['Menu Category ', 'Menu Items', '             per serve',
#        'Energy (kcal)', ' Protein(g)', 'Total fat', 'Sat Fat', 'Trans fat',
#        'Cholester', 'Total Carb', 'Total Sugar', 'Added sugar', 'Sodium (mg)'],
#       dtype='object')

# %%
df.head()
# Out:
#    Menu Category           Menu Items              per serve  Energy (kcal)  \
# 0    Regular Menu   McSpicyåAC Panee                   199 g         652.76
# 1    Regular Menu  Spicy Paneer Wrap                   250 g         674.68
# 2  Breakfast Menu   Double Cheese Mt                    100g         273.78
# 3  Breakfast Menu   Sausage McMuffir                    112g         281.44
# 4     McCafe Menu       FlatWhite(R)                 347.5ml         215.72
#
#     Protein(g)  Total fat  Sat Fat  Trans fat  Cholester  Total Carb  \
# 0        20.29      39.45    17.12       0.18      21.85       52.33
# 1        20.96      39.10    19.73       0.26      40.93       59.27
# 2         9.58      12.82     8.84       0.21      37.75       29.00
# 3        16.25      10.81     6.04       0.17      53.02       28.62
# 4        10.36      12.02     8.84       0.35      36.48       19.08
#
#    Total Sugar  Added sugar  Sodium (mg)
# 0         8.35         5.27      1074.58
# 1         3.50         1.08       107.46
# 2         2.59         0.75       622.95
# 3         2.38         0.75       742.60
# 4        14.41         0.00       154.98

# %%
df.tail()
# Out:
#       Menu Category            Menu Items              per serve  \
# 7      Desserts Menu    Regular McFlurry                 147.38g
# 8      Gourmet Menu   American Triple Cl                    195g
# 9      Gourmet Menu     Cheese Lava Burg                   240g
# 10  Condiments Menu       BBQdipingsauce                     25g
# 11  Condiments Menu         Piri Piri Mix                     5g
#
#     Energy (kcal)   Protein(g)  Total fat  Sat Fat  Trans fat  Cholester  \
# 7          209.39         3.58       6.81     4.07       0.12       8.00
# 8          457.94        24.43      22.65    11.56       0.17      71.23
# 9          671.06        14.99      33.48    14.12       0.21      33.21
# 10          54.89         0.26       0.49     0.15       0.04       0.25
# 11          17.13         0.51       0.36     0.08       0.01       0.05
#
#     Total Carb  Total Sugar  Added sugar  Sodium (mg)
# 7        33.42        25.35        19.23       150.90
# 8        37.45         7.64         3.84      1396.17
# 9        74.25        16.27        10.01      1153.99
# 10       12.36         7.65         2.50       113.23
# 11        2.50         0.66         0.40       414.71

# %%
df.shape
# Out:
# (12, 13)

# %%
df.columns
# Out:
# Index(['Menu Category ', 'Menu Items', '             per serve',
#        'Energy (kcal)', ' Protein(g)', 'Total fat', 'Sat Fat', 'Trans fat',
#        'Cholester', 'Total Carb', 'Total Sugar', 'Added sugar', 'Sodium (mg)'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Menu Category              object
# Menu Items                 object
#              per serve     object
# Energy (kcal)             float64
#  Protein(g)               float64
# Total fat                 float64
# Sat Fat                   float64
# Trans fat                 float64
# Cholester                 float64
# Total Carb                float64
# Total Sugar               float64
# Added sugar               float64
# Sodium (mg)               float64
# dtype: object

# %%
#checking the null values
df.isnull().sum()
# Out:
# Menu Category             0
# Menu Items                0
#              per serve    0
# Energy (kcal)             0
#  Protein(g)               0
# Total fat                 0
# Sat Fat                   0
# Trans fat                 0
# Cholester                 0
# Total Carb                0
# Total Sugar               0
# Added sugar               0
# Sodium (mg)               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Menu Category           12 non-null     object
#  1   Menu Items              12 non-null     object
#  2                per serve  12 non-null     object
#  3   Energy (kcal)           12 non-null     float64
#  4    Protein(g)             12 non-null     float64
#  5   Total fat               12 non-null     float64
#  6   Sat Fat                 12 non-null     float64
#  7   Trans fat               12 non-null     float64
#  8   Cholester               12 non-null     float64
#  9   Total Carb              12 non-null     float64
#  10  Total Sugar             12 non-null     float64
#  11  Added sugar             12 non-null     float64
#  12  Sodium (mg)             12 non-null     float64
# dtypes: float64(10), object(3)
# memory usage: 1.3+ KB

# %%
#check null value by using heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#cheking no.of unique values in each column
df.nunique()
# Out:
# Menu Category              6
# Menu Items                12
#              per serve    12
# Energy (kcal)             12
#  Protein(g)               12
# Total fat                 12
# Sat Fat                   11
# Trans fat                  9
# Cholester                 12
# Total Carb                12
# Total Sugar               12
# Added sugar               11
# Sodium (mg)               12
# dtype: int64

# %%
# checking the value counts of each column
for col in df.columns:
    print(df[col].value_counts())
    print('\n')
# Out:
# Regular Menu        2
# Breakfast Menu      2
# McCafe Menu         2
# Desserts Menu       2
# Gourmet Menu        2
# Condiments Menu     2
# Name: Menu Category , dtype: int64
#
#
# McSpicyåAC Panee       1
# Spicy Paneer Wrap      1
# Double Cheese Mt       1
# Sausage McMuffir       1
# FlatWhite(R)           1
# Mocha (S)              1
# Small McFlurry -o      1
# Regular McFlurry       1
# American Triple Cl     1
# Cheese Lava Burg      1
# BBQdipingsauce         1
# Piri Piri Mix          1
# Name: Menu Items, dtype: int64
#
#
# 199 g       1
# 250 g       1
# 100g        1
# 112g        1
# 347.5ml     1
# 242.5 ml    1
# 86.79g      1
# 147.38g     1
# 195g        1
# 240g        1
# 25g         1
# 5g          1
# Name:              per serve, dtype: int64
#
#
# 652.76    1
# 674.68    1
# 273.78    1
# 281.44    1
# 215.72    1
# 185.85    1
# 116.36    1
# 209.39    1
# 457.94    1
# 671.06    1
# 54.89     1
# 17.13     1
# Name: Energy (kcal), dtype: int64
#
#
# 20.29    1
# 20.96    1
# 9.58     1
# 16.25    1
# 10.36    1
# 7.15     1
# 2.05     1
# 3.58     1
# 24.43    1
# 14.99    1
# 0.26     1
# 0.51     1
# Name:  Protein(g), dtype: int64
#
#
# 39.45    1
# 39.10    1
# 12.82    1
# 10.81    1
# 12.02    1
# 8.20     1
# 3.70     1
# 6.81     1
# 22.65    1
# 33.48    1
# 0.49     1
# 0.36     1
# Name: Total fat, dtype: int64
#
#
# 8.84     2
# 17.12    1
# 19.73    1
# 6.04     1
# 5.94     1
# 2.25     1
# 4.07     1
# 11.56    1
# 14.12    1
# 0.15     1
# 0.08     1
# Name: Sat Fat, dtype: int64
#
#
# 0.26    2
# 0.21    2
# 0.17    2
# 0.18    1
# 0.35    1
# 0.07    1
# 0.12    1
# 0.04    1
# 0.01    1
# Name: Trans fat, dtype: int64
#
#
# 21.85    1
# 40.93    1
# 37.75    1
# 53.02    1
# 36.48    1
# 24.43    1
# 4.80     1
# 8.00     1
# 71.23    1
# 33.21    1
# 0.25     1
# 0.05     1
# Name: Cholester, dtype: int64
#
#
# 52.33    1
# 59.27    1
# 29.00    1
# 28.62    1
# 19.08    1
# 22.59    1
# 18.69    1
# 33.42    1
# 37.45    1
# 74.25    1
# 12.36    1
# 2.50     1
# Name: Total Carb, dtype: int64
#
#
# 8.35     1
# 3.50     1
# 2.59     1
# 2.38     1
# 14.41    1
# 17.57    1
# 14.49    1
# 25.35    1
# 7.64     1
# 16.27    1
# 7.65     1
# 0.66     1
# Name: Total Sugar, dtype: int64
#
#
# 0.75     2
# 5.27     1
# 1.08     1
# 0.00     1
# 6.08     1
# 10.80    1
# 19.23    1
# 3.84     1
# 10.01    1
# 2.50     1
# 0.40     1
# Name: Added sugar, dtype: int64
#
#
# 1074.58    1
# 107.46     1
# 622.95     1
# 742.60     1
# 154.98     1
# 132.84     1
# 80.73      1
# 150.90     1
# 1396.17    1
# 1153.99    1
# 113.23     1
# 414.71     1
# Name: Sodium (mg), dtype: int64

# %%
# Checking for duplicate values
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
# List of numerical columns
numerical_cols = ['Energy (kcal)', ' Protein(g)', 'Total fat', 'Sat Fat', 'Trans fat',
       'Cholester', 'Total Carb', 'Total Sugar', 'Added sugar', 'Sodium (mg)']

# Create a new DataFrame containing only the numerical columns
num_df = df[numerical_cols]

# Print the new DataFrame
print(num_df)
# Out:
#     Energy (kcal)   Protein(g)  Total fat  Sat Fat  Trans fat  Cholester  \
# 0          652.76        20.29      39.45    17.12       0.18      21.85
# 1          674.68        20.96      39.10    19.73       0.26      40.93
# 2          273.78         9.58      12.82     8.84       0.21      37.75
# 3          281.44        16.25      10.81     6.04       0.17      53.02
# 4          215.72        10.36      12.02     8.84       0.35      36.48
# 5          185.85         7.15       8.20     5.94       0.26      24.43
# 6          116.36         2.05       3.70     2.25       0.07       4.80
# 7          209.39         3.58       6.81     4.07       0.12       8.00
# 8          457.94        24.43      22.65    11.56       0.17      71.23
# 9          671.06        14.99      33.48    14.12       0.21      33.21
# 10          54.89         0.26       0.49     0.15       0.04       0.25
# 11          17.13         0.51       0.36     0.08       0.01       0.05
#
#     Total Carb  Total Sugar  Added sugar  Sodium (mg)
# 0        52.33         8.35         5.27      1074.58
# 1        59.27         3.50         1.08       107.46
# 2        29.00         2.59         0.75       622.95
# 3        28.62         2.38         0.75       742.60
# 4        19.08        14.41         0.00       154.98
# 5        22.59        17.57         6.08       132.84
# 6        18.69        14.49        10.80        80.73
# 7        33.42        25.35        19.23       150.90
# 8        37.45         7.64         3.84      1396.17
# 9        74.25        16.27        10.01      1153.99
# 10       12.36         7.65         2.50       113.23
# 11        2.50         0.66         0.40       414.71

# %%
# List of categorical columns
categorical_cols = ['Menu Category ', 'Menu Items', '             per serve']

# Create a new DataFrame containing only the categorical columns
cat_df = df[categorical_cols]

# Print the new DataFrame
print(cat_df)
# Out:
#       Menu Category            Menu Items              per serve
# 0       Regular Menu    McSpicyåAC Panee                   199 g
# 1       Regular Menu   Spicy Paneer Wrap                   250 g
# 2     Breakfast Menu    Double Cheese Mt                    100g
# 3     Breakfast Menu    Sausage McMuffir                    112g
# 4        McCafe Menu        FlatWhite(R)                 347.5ml
# 5        McCafe Menu            Mocha (S)               242.5 ml
# 6      Desserts Menu    Small McFlurry -o                 86.79g
# 7      Desserts Menu    Regular McFlurry                 147.38g
# 8      Gourmet Menu   American Triple Cl                    195g
# 9      Gourmet Menu     Cheese Lava Burg                   240g
# 10  Condiments Menu       BBQdipingsauce                     25g
# 11  Condiments Menu         Piri Piri Mix                     5g

# %%
description = num_df.describe()
description
# Out:
#        Energy (kcal)   Protein(g)  Total fat    Sat Fat  Trans fat  Cholester  \
# count      12.000000    12.000000  12.000000  12.000000  12.000000  12.000000
# mean      317.583333    10.867500  15.824167   8.228333   0.170833  27.666667
# std       238.735052     8.458119  14.357637   6.414631   0.098577  22.145950
# min        17.130000     0.260000   0.360000   0.080000   0.010000   0.050000
# 25%       168.477500     3.197500   6.032500   3.615000   0.107500   7.200000
# 50%       244.750000     9.970000  11.415000   7.440000   0.175000  28.820000
# 75%       506.645000    17.260000  25.357500  12.200000   0.222500  38.545000
# max       674.680000    24.430000  39.450000  19.730000   0.350000  71.230000
#
#        Total Carb  Total Sugar  Added sugar  Sodium (mg)
# count   12.000000    12.000000    12.000000    12.000000
# mean    32.463333    10.071667     5.059167   512.095000
# std     20.626994     7.556211     5.781454   476.315235
# min      2.500000     0.660000     0.000000    80.730000
# 25%     18.982500     3.272500     0.750000   127.937500
# 50%     28.810000     8.000000     3.170000   284.845000
# 75%     41.170000    14.935000     7.062500   825.595000
# max     74.250000    25.350000    19.230000  1396.170000

# %%
#check for outliers
df_outliers = df[numerical_cols]
df_outliers.plot(kind='box', subplots=True, layout=(7, 4), fontsize=10, figsize=(12, 18))
plt.show()

# %%
#remove outliers with z-score method
from scipy.stats import zscore
out_df = df[numerical_cols]
z = np.abs(zscore(out_df))
z
# Out:
#     Energy (kcal)   Protein(g)  Total fat   Sat Fat  Trans fat  Cholester  \
# 0        1.466398     1.163554   1.718694  1.447791   0.097125   0.274331
# 1        1.562298     1.246290   1.693232  1.872765   0.944759   0.625536
# 2        0.191640     0.158989   0.218542  0.099595   0.414988   0.475559
# 3        0.158127     0.664668   0.364762  0.356317   0.008830   1.195735
# 4        0.445652     0.062670   0.276739  0.099595   1.898348   0.415662
# 5        0.576333     0.459062   0.554630  0.372599   0.944759   0.152650
# 6        0.880352     1.088845   0.881989  0.973426   1.068373   1.078457
# 7        0.473346     0.899910   0.655748  0.677083   0.538601   0.927536
# 8        0.614060     1.674789   0.496555  0.542481   0.008830   2.054571
# 9        1.546461     0.509074   1.284398  0.959314   0.414988   0.261439
# 10       1.149283     1.309886   1.115505  1.315359   1.386236   1.293048
# 11       1.314483     1.279014   1.124962  1.326757   1.704099   1.302480
#
#     Total Carb  Total Sugar  Added sugar  Sodium (mg)
# 0     1.005966     0.237979     0.038089     1.233419
# 1     1.357379     0.908376     0.718868     0.887285
# 2     0.175369     1.034162     0.778485     0.243083
# 3     0.194611     1.063189     0.778485     0.505452
# 4     0.677677     0.599671     0.913979     0.783083
# 5     0.499945     1.036466     0.184422     0.831632
# 6     0.697425     0.610729     1.037128     0.945899
# 7     0.048442     2.111865     2.560075     0.792030
# 8     0.252504     0.336120     0.220252     1.938603
# 9     2.115905     0.856772     0.894408     1.407550
# 10    1.017950     0.334738     0.462334     0.874633
# 11    1.517220     1.300938     0.841716     0.213546

# %%
#threshold value = 3
z_score_threshold = 3

# %%
outliers = np.any(z > z_score_threshold, axis=1)

# %%
df_out = df[~outliers]

# %%
df_out.shape
# Out:
# (12, 13)

# %%
#shape of old and new data frame
print("old df_",df.shape[0])
print("New df_",df_out.shape[0])
# Out:
# old df_ 12
# New df_ 12

# %%
#view data loss by persentage 
print("data loss percentage_",((df.shape[0]-df_out.shape[0])/df.shape[0])*100)
# Out:
# data loss percentage_ 0.0

# %%
df=df_out

# %%
# check skewness 
df.skew()
# Out:
# Energy (kcal)    0.577122
#  Protein(g)      0.208123
# Total fat        0.779545
# Sat Fat          0.450605
# Trans fat       -0.030320
# Cholester        0.419016
# Total Carb       0.734596
# Total Sugar      0.599021
# Added sugar      1.515764
# Sodium (mg)      0.796416
# dtype: float64

# %%
#lets check how the data hase been distributed in numerical columns
plt.figure(figsize=(10, 18))  
plotnumber = 1
for col in numerical_cols:
    if plotnumber <=7:
        plt.subplot(7, 1, plotnumber)
        sns.distplot(df[col], color="m")
        plt.xlabel(col, fontsize=12)
        plt.xticks(rotation=0, fontsize=10)
        plt.yticks(rotation=0, fontsize=10)
        plotnumber += 1

plt.tight_layout()
plt.show()

# %%
# apply cube root transformation to reduce skewness
for col in numerical_cols:
    if df[col].skew() > 0.5:
        df[col] = np.cbrt(df[col])

# %%
#checking skewness again
df.skew()
# Out:
# Energy (kcal)   -0.387029
#  Protein(g)      0.208123
# Total fat       -0.322375
# Sat Fat          0.450605
# Trans fat       -0.030320
# Cholester        0.419016
# Total Carb      -0.613415
# Total Sugar     -0.338109
# Added sugar     -0.163505
# Sodium (mg)      0.368444
# dtype: float64

# %%
#lets check again how the data hase been distributed in numerical columns
plt.figure(figsize=(10, 18))  
plotnumber = 1
for col in numerical_cols:
    if plotnumber <= 7:
        plt.subplot(7, 1, plotnumber)
        sns.distplot(df[col], color="m")
        plt.xlabel(col, fontsize=12)
        plt.xticks(rotation=0, fontsize=10)
        plt.yticks(rotation=0, fontsize=10)
        plotnumber += 1

plt.tight_layout()
plt.show()

# %%
# Encode categorical columns using Ordinal Encoder
from sklearn.preprocessing import OrdinalEncoder

OE = OrdinalEncoder()
for i in df.columns:
    if df[i].dtype == 'object':
        df[i] = OE.fit_transform(df[i].values.reshape(-1,1))


df
# Out:
#     Menu Category   Menu Items               per serve  Energy (kcal)  \
# 0              5.0         5.0                     4.0       8.674634
# 1              5.0        11.0                     7.0       8.770667
# 2              0.0         3.0                     0.0       6.493326
# 3              0.0         9.0                     1.0       6.553329
# 4              4.0         4.0                     9.0       5.997406
# 5              4.0         6.0                     6.0       5.706733
# 6              2.0        10.0                    11.0       4.882039
# 7              2.0         8.0                     2.0       5.938161
# 8              3.0         0.0                     3.0       7.707902
# 9              3.0         2.0                     5.0       8.754952
# 10             1.0         1.0                     8.0       3.800415
# 11             1.0         7.0                    10.0       2.577819
#
#      Protein(g)  Total fat  Sat Fat  Trans fat  Cholester  Total Carb  \
# 0         20.29   3.404205    17.12       0.18      21.85    3.740390
# 1         20.96   3.394107    19.73       0.26      40.93    3.898926
# 2          9.58   2.340432     8.84       0.21      37.75    3.072317
# 3         16.25   2.211101     6.04       0.17      53.02    3.058838
# 4         10.36   2.290700     8.84       0.35      36.48    2.672142
# 5          7.15   2.016530     5.94       0.26      24.43    2.826867
# 6          2.05   1.546680     2.25       0.07       4.80    2.653810
# 7          3.58   1.895465     4.07       0.12       8.00    3.221085
# 8         24.43   2.829368    11.56       0.17      71.23    3.345676
# 9         14.99   3.223011    14.12       0.21      33.21    4.203059
# 10         0.26   0.788374     0.15       0.04       0.25    2.312098
# 11         0.51   0.711379     0.08       0.01       0.05    1.357209
#
#     Total Sugar  Added sugar  Sodium (mg)
# 0      2.028751     1.740218    10.242664
# 1      1.518294     1.025986     4.754253
# 2      1.373304     0.908560     8.540522
# 3      1.335136     0.908560     9.055623
# 4      2.433444     0.000000     5.371454
# 5      2.599704     1.825161     5.102421
# 6      2.437939     2.210419     4.321936
# 7      2.937600     2.679126     5.323898
# 8      1.969538     1.565947    11.176679
# 9      2.533937     2.155153    10.488998
# 10     1.970397     1.357209     4.837866
# 11     0.870659     0.736806     7.457298

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 0 to 11
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Menu Category           12 non-null     float64
#  1   Menu Items              12 non-null     float64
#  2                per serve  12 non-null     float64
#  3   Energy (kcal)           12 non-null     float64
#  4    Protein(g)             12 non-null     float64
#  5   Total fat               12 non-null     float64
#  6   Sat Fat                 12 non-null     float64
#  7   Trans fat               12 non-null     float64
#  8   Cholester               12 non-null     float64
#  9   Total Carb              12 non-null     float64
#  10  Total Sugar             12 non-null     float64
#  11  Added sugar             12 non-null     float64
#  12  Sodium (mg)             12 non-null     float64
# dtypes: float64(13)
# memory usage: 1.3 KB

# %%
df.describe()
# Out:
#        Menu Category   Menu Items               per serve  Energy (kcal)  \
# count       12.000000   12.000000               12.000000      12.000000
# mean         2.500000    5.500000                5.500000       6.321449
# std          1.783765    3.605551                3.605551       1.966439
# min          0.000000    0.000000                0.000000       2.577819
# 25%          1.000000    2.750000                2.750000       5.500559
# 50%          2.500000    5.500000                5.500000       6.245366
# 75%          4.000000    8.250000                8.250000       7.949585
# max          5.000000   11.000000               11.000000       8.770667
#
#         Protein(g)  Total fat    Sat Fat  Trans fat  Cholester  Total Carb  \
# count    12.000000  12.000000  12.000000  12.000000  12.000000   12.000000
# mean     10.867500   2.220946   8.228333   0.170833  27.666667    3.030201
# std       8.458119   0.909714   6.414631   0.098577  22.145950    0.762710
# min       0.260000   0.711379   0.080000   0.010000   0.050000    1.357209
# 25%       3.197500   1.808269   3.615000   0.107500   7.200000    2.667559
# 50%       9.970000   2.250900   7.440000   0.175000  28.820000    3.065578
# 75%      17.260000   2.927779  12.200000   0.222500  38.545000    3.444355
# max      24.430000   3.404205  19.730000   0.350000  71.230000    4.203059
#
#        Total Sugar  Added sugar  Sodium (mg)
# count    12.000000    12.000000    12.000000
# mean      2.000725     1.426095     7.222801
# std       0.621462     0.750978     2.563686
# min       0.870659     0.000000     4.321936
# 25%       1.482047     0.908560     5.036282
# 50%       1.999574     1.461578     6.414376
# 75%       2.461938     1.907659     9.352383
# max       2.937600     2.679126    11.176679

# %%
# check correlation 
cor = df.corr()
cor
# Out:
#                         Menu Category   Menu Items               per serve  \
# Menu Category                 1.000000    0.070675                0.254431
# Menu Items                    0.070675    1.000000                0.202797
#              per serve        0.254431    0.202797                1.000000
# Energy (kcal)                 0.565173   -0.064038               -0.483303
#  Protein(g)                   0.485387   -0.128079               -0.452680
# Total fat                     0.623717   -0.033217               -0.428266
# Sat Fat                       0.686693   -0.017884               -0.295074
# Trans fat                     0.560950   -0.052434               -0.221246
# Cholester                     0.153636   -0.232907               -0.538669
# Total Carb                    0.491256   -0.048973               -0.493048
# Total Sugar                   0.405826   -0.110422                0.051532
# Added sugar                   0.094006    0.069858               -0.159405
# Sodium (mg)                  -0.064013   -0.493170               -0.560602
#
#                         Energy (kcal)   Protein(g)  Total fat   Sat Fat  \
# Menu Category                0.565173     0.485387   0.623717  0.686693
# Menu Items                  -0.064038    -0.128079  -0.033217 -0.017884
#              per serve      -0.483303    -0.452680  -0.428266 -0.295074
# Energy (kcal)                1.000000     0.875651   0.986858  0.936376
#  Protein(g)                  0.875651     1.000000   0.886569  0.868064
# Total fat                    0.986858     0.886569   1.000000  0.962889
# Sat Fat                      0.936376     0.868064   0.962889  1.000000
# Trans fat                    0.621087     0.542147   0.677081  0.639479
# Cholester                    0.652120     0.847188   0.657699  0.580497
# Total Carb                   0.962985     0.739602   0.916357  0.842972
# Total Sugar                  0.199862    -0.115996   0.156215  0.014785
# Added sugar                  0.177294    -0.103510   0.090844 -0.032902
# Sodium (mg)                  0.488386     0.628478   0.484757  0.408989
#
#                         Trans fat  Cholester  Total Carb  Total Sugar  \
# Menu Category            0.560950   0.153636    0.491256     0.405826
# Menu Items              -0.052434  -0.232907   -0.048973    -0.110422
#              per serve  -0.221246  -0.538669   -0.493048     0.051532
# Energy (kcal)            0.621087   0.652120    0.962985     0.199862
#  Protein(g)              0.542147   0.847188    0.739602    -0.115996
# Total fat                0.677081   0.657699    0.916357     0.156215
# Sat Fat                  0.639479   0.580497    0.842972     0.014785
# Trans fat                1.000000   0.595844    0.532333     0.265743
# Cholester                0.595844   1.000000    0.522240    -0.149768
# Total Carb               0.532333   0.522240    1.000000     0.349212
# Total Sugar              0.265743  -0.149768    0.349212     1.000000
# Added sugar             -0.327919  -0.277975    0.367297     0.618497
# Sodium (mg)              0.044916   0.565121    0.387285    -0.254716
#
#                         Added sugar  Sodium (mg)
# Menu Category              0.094006    -0.064013
# Menu Items                 0.069858    -0.493170
#              per serve    -0.159405    -0.560602
# Energy (kcal)              0.177294     0.488386
#  Protein(g)               -0.103510     0.628478
# Total fat                  0.090844     0.484757
# Sat Fat                   -0.032902     0.408989
# Trans fat                 -0.327919     0.044916
# Cholester                 -0.277975     0.565121
# Total Carb                 0.367297     0.387285
# Total Sugar                0.618497    -0.254716
# Added sugar                1.000000     0.018040
# Sodium (mg)                0.018040     1.000000

# %%
# Visualizing the correlation by plotting a heatmap
plt.figure(figsize=(20, 15))
sns.heatmap(df.corr(), linewidths=0.1, fmt=".1g", linecolor="black", annot=True, cmap="Blues")
plt.yticks(rotation=0)
plt.show()

# %%
#visulaizing the correlation  between label and features using bar plot 
#Votes
plt.figure(figsize=(22, 7))
df.corr()['Energy (kcal)'].sort_values(ascending=False).drop(['Energy (kcal)']).plot(kind='bar', color='magenta')
plt.xlabel('Features', fontsize=15)
plt.ylabel('Target', fontsize=15)
plt.title('Correlation between Features and Label', fontsize=20)
plt.show()

# %%
#Separating features and label
X_reg = df.drop('Energy (kcal)',axis=1)
y_reg= df['Energy (kcal)']

# %%
#Feature Scalling using standard scalarization
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_reg = pd.DataFrame(scaler.fit_transform(X_reg), columns=X_reg.columns)
X_reg
# Out:
#     Menu Category   Menu Items               per serve   Protein(g)  \
# 0          1.46385   -0.144841               -0.434524     1.163554
# 1          1.46385    1.593255                0.434524     1.246290
# 2         -1.46385   -0.724207               -1.593255    -0.158989
# 3         -1.46385    1.013890               -1.303572     0.664668
# 4          0.87831   -0.434524                1.013890    -0.062670
# 5          0.87831    0.144841                0.144841    -0.459062
# 6         -0.29277    1.303572                1.593255    -1.088845
# 7         -0.29277    0.724207               -1.013890    -0.899910
# 8          0.29277   -1.593255               -0.724207     1.674789
# 9          0.29277   -1.013890               -0.144841     0.509074
# 10        -0.87831   -1.303572                0.724207    -1.309886
# 11        -0.87831    0.434524                1.303572    -1.279014
#
#     Total fat   Sat Fat  Trans fat  Cholester  Total Carb  Total Sugar  \
# 0    1.358530  1.447791   0.097125  -0.274331    0.972542     0.047102
# 1    1.346937  1.872765   0.944759   0.625536    1.189643    -0.810802
# 2    0.137185  0.099595   0.414988   0.475559    0.057673    -1.054483
# 3   -0.011303 -0.356317  -0.008830   1.195735    0.039216    -1.118629
# 4    0.080086  0.099595   1.898348   0.415662   -0.490332     0.727253
# 5   -0.234695 -0.372599   0.944759  -0.152650   -0.278448     1.006680
# 6   -0.774141 -0.973426  -1.068373  -1.078457   -0.515436     0.734807
# 7   -0.373693 -0.677083  -0.538601  -0.927536    0.261398     1.574568
# 8    0.698545  0.542481  -0.008830   2.054571    0.432016    -0.052415
# 9    1.150497  0.959314   0.414988   0.261439    1.606127     0.896148
# 10  -1.644773 -1.315359  -1.386236  -1.293048   -0.983381    -0.050971
# 11  -1.733173 -1.326757  -1.704099  -1.302480   -2.291018    -1.899258
#
#     Added sugar  Sodium (mg)
# 0      0.436884     1.230316
# 1     -0.556476    -1.005706
# 2     -0.719792     0.536850
# 3     -0.719792     0.746706
# 4     -1.983425    -0.754253
# 5      0.555024    -0.863859
# 6      1.090844    -1.181835
# 7      1.742725    -0.773628
# 8      0.194507     1.610841
# 9      1.013979     1.330674
# 10    -0.095808    -0.971641
# 11    -0.958669     0.095536

# %%
#checking  variance inflation factor (vif)
from statsmodels.stats.outliers_influence import variance_inflation_factor

Vif = pd.DataFrame()
Vif['VIF Values'] = [variance_inflation_factor(X_reg.values, i) for i in range(len(X_reg.columns))]
Vif['Features'] = X_reg.columns
Vif
# Out:
#     VIF Values                Features
# 0          inf          Menu Category
# 1          inf              Menu Items
# 2          inf               per serve
# 3          inf              Protein(g)
# 4          inf               Total fat
# 5          inf                 Sat Fat
# 6          inf               Trans fat
# 7          inf               Cholester
# 8          inf              Total Carb
# 9          inf             Total Sugar
# 10         inf             Added sugar
# 11         inf             Sodium (mg)

# %%
y_reg.value_counts()
# Out:
# 8.674634    1
# 8.770667    1
# 6.493326    1
# 6.553329    1
# 5.997406    1
# 5.706733    1
# 4.882039    1
# 5.938161    1
# 7.707902    1
# 8.754952    1
# 3.800415    1
# 2.577819    1
# Name: Energy (kcal), dtype: int64

# %% [raw]
# modelling

# %%
#import liabraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
#finding the best random state

MaxAccu = 0
MaxRs = 0

for i in range(1, 200):
    X_reg_train, X_reg_test, y_reg_train, y_reg_test = train_test_split(X_reg, y_reg, test_size=0.3, random_state=i)
    lr = LinearRegression()
    lr.fit(X_reg_train, y_reg_train)
    pred = lr.predict(X_reg_test)
    acc = r2_score(y_reg_test, pred)
    if acc > MaxAccu:
        MaxAccu = acc
        MaxRs = i

print("Maximum R2 score is", MaxAccu, "on Random State", MaxRs)
# Out:
# Maximum R2 score is 0.990796426860993 on Random State 23

# %%
X_reg_train, X_reg_test, y_reg_train,y_reg_test = train_test_split(X_reg, y_reg, test_size=0.3, random_state=23)

# %%
#modelling
#import liabraries
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
lr.fit(X_reg_train,y_reg_train)
pred_lr = lr.predict(X_reg_test)
pred_train = lr.predict(X_reg_train)

print("R2_score:",r2_score(y_reg_test,pred_lr))
print("R2_score on training Data:",r2_score(y_reg_train,pred_train)*100)
print ("MeanAbsoluteError:",mean_absolute_error(y_reg_test,pred_lr))
print ("MeanSquaredError:",mean_squared_error(y_reg_test,pred_lr))
print ("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_reg_test,pred_lr)))
# Out:
# R2_score: 0.990796426860993
# R2_score on training Data: 100.0
# MeanAbsoluteError: 0.0777303049474336
# MeanSquaredError: 0.015282007655624817
# Root Mean Squared Error: 0.12362041763246401

# %%
Rd = Ridge()
Rd.fit(X_reg_train, y_reg_train)
pred_Rd = Rd.predict(X_reg_test)
pred_train = Rd.predict(X_reg_train)

print("R2_score:", r2_score(y_reg_test, pred_Rd))
print("R2_score on training Data:", r2_score(y_reg_train, pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_reg_test, pred_Rd))
print("Mean Squared Error:", mean_squared_error(y_reg_test, pred_Rd))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg_test, pred_Rd)))
# Out:
# R2_score: 0.9473362332277709
# R2_score on training Data: 99.44857486287479
# Mean Absolute Error: 0.2764247765029568
# Mean Squared Error: 0.08744517752309383
# Root Mean Squared Error: 0.2957113077362681

# %%
Dtr = DecisionTreeRegressor()
Dtr.fit(X_reg_train, y_reg_train)
pred_Dtr = Dtr.predict(X_reg_test)
pred_train = Dtr.predict(X_reg_train)

print("R2_score:", r2_score(y_reg_test, pred_Dtr))
print("R2_score on training Data:", r2_score(y_reg_train, pred_train))
print("Mean Absolute Error:", mean_absolute_error(y_reg_test, pred_Dtr))
print("Mean Squared Error:", mean_squared_error(y_reg_test, pred_Dtr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg_test, pred_Dtr)))
# Out:
# R2_score: -0.06833096703842623
# R2_score on training Data: 1.0
# Mean Absolute Error: 1.0951281682386218
# Mean Squared Error: 1.7739025670179867
# Root Mean Squared Error: 1.331879336508374

# %%
Rfr = RandomForestRegressor()
Rfr.fit(X_reg_train, y_reg_train)
pred_Rfr = Rfr.predict(X_reg_test)
pred_train = Rfr.predict(X_reg_train)

print("R2_score:", r2_score(y_reg_test, pred_Rfr))
print("R2_score on training Data:", r2_score(y_reg_train, pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_reg_test, pred_Rfr))
print("Mean Squared Error:", mean_squared_error(y_reg_test, pred_Rfr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg_test, pred_Rfr)))
# Out:
# R2_score: 0.008437661140405894
# R2_score on training Data: 95.5672767226827
# Mean Absolute Error: 0.9542062514601817
# Mean Squared Error: 1.6464326435630938
# Root Mean Squared Error: 1.2831339148986336

# %%
Svr = SVR()
Svr.fit(X_reg_train, y_reg_train)
pred_Svr = Svr.predict(X_reg_test)
pred_train = Svr.predict(X_reg_train)

print("R2_score:", r2_score(y_reg_test, pred_Rfr))
print("R2_score on training Data:", r2_score(y_reg_train, pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_reg_test, pred_Svr))
print("Mean Squared Error:", mean_squared_error(y_reg_test, pred_Svr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg_test, pred_Svr)))
# Out:
# R2_score: 0.008437661140405894
# R2_score on training Data: 78.787445732557
# Mean Absolute Error: 1.174944696446522
# Mean Squared Error: 2.32299705589576
# Root Mean Squared Error: 1.5241381354377823

# %%
Knn = KNeighborsRegressor()
Knn.fit(X_reg_train, y_reg_train)
pred_Knn = Knn.predict(X_reg_test)
pred_train = Knn.predict(X_reg_train)

print("R2_score:", r2_score(y_reg_test, pred_Knn))
print("R2_score on training Data:", r2_score(y_reg_train, pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_reg_test, pred_Knn))
print("Mean Squared Error:", mean_squared_error(y_reg_test, pred_Knn))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg_test, pred_Knn)))
# Out:
# R2_score: -0.04224129475689131
# R2_score on training Data: 64.24151157250941
# Mean Absolute Error: 1.0297557498758279
# Mean Squared Error: 1.7305821559648749
# Root Mean Squared Error: 1.3155159276743382

# %% [raw]
# Cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(lr, X_reg, y_reg, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg_test, pred_lr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [ 0.69591794 -2.06795927  0.94106885  0.49927627  0.86189421]
# Mean Cross Validation Score: 0.18603960087926982
# Difference between R2 score and Cross Validation score: 80.47568259817231

# %%
scores = cross_val_score(Rd, X_reg, y_reg, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg_test, pred_Rd) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [ 0.61238486 -3.32057213  0.93091959  0.65295883 -0.10328065]
# Mean Cross Validation Score: -0.24551790035875948
# Difference between R2 score and Cross Validation score: 119.28541335865303

# %%
scores = cross_val_score(Dtr, X_reg, y_reg, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg_test, pred_Dtr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [ -2.73989363 -18.52157346  -4.68702979  -4.34928336  -7.66950876]
# Mean Cross Validation Score: -7.593457801636904
# Difference between R2 score and Cross Validation score: 752.5126834598477

# %%
scores = cross_val_score(Rfr, X_reg, y_reg, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg_test, pred_Rfr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [ -0.19749976  -3.75042234   0.38810037  -4.38357641 -15.61786976]
# Mean Cross Validation Score: -4.712253581286314
# Difference between R2 score and Cross Validation score: 472.069124242672

# %%
scores = cross_val_score(Svr, X_reg, y_reg, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg_test, pred_Svr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [-2.04831798e+00 -2.01197371e+00 -1.50976598e-02 -8.80577827e+00
#  -2.93979393e+01]
# Mean Cross Validation Score: -8.45582139116972
# Difference between R2 score and Cross Validation score: 805.6798842076487

# %%
scores = cross_val_score(Knn, X_reg, y_reg, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg_test, pred_Knn) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [ -0.96949148 -14.55187436   0.80859755  -5.80463851 -19.26754373]
# Mean Cross Validation Score: -7.956990106469871
# Difference between R2 score and Cross Validation score: 791.474881171298

# %% [raw]
# our best fit model is lr (Linear Regressor()) for "Energy"

# %% [raw]
# HyperparameterTuning

# %%
#GridSearchCV
from sklearn.model_selection import GridSearchCV

# %%
lr = LinearRegression()

# Define the hyperparameters and their potential values
parameters = {
    "fit_intercept": [True, False],  # Whether to calculate the intercept
     "copy_X": [True, False],          # Whether to copy data before fitting
    "positive": [True, False],        # Whether to constrain the coefficients to be positive
    "n_jobs": [None, -1]              # Number of jobs to run in parallel (-1 means using all processors)
}


# Create a GridSearchCV object
grid = GridSearchCV(estimator=lr, param_grid=parameters, cv=5, n_jobs=-1)

# Fit the grid search to your data
grid.fit(X_reg_train, y_reg_train)

# Get the best hyperparameters
best_params = grid.best_params_
print("Best Parameters:", best_params)

# Evaluate the model with the best parameters on the test data
score = grid.score(X_reg_test, y_reg_test)
print("Test Score:", score)
# Out:
# Best Parameters: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': True}
# Test Score: 0.924576284122168

# %%
# Create a Linear Regression model with specified hyperparameters
Model = LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, positive=True)

# Fit the model to the training data
Model.fit(X_reg_train, y_reg_train)

# Make predictions on the test data
pred = Model.predict(X_reg_test)

# Calculate regression metrics
print("R2_score:", r2_score(y_reg_test, pred))
print("Mean Absolute Error:", mean_absolute_error(y_reg_test, pred))
print("Mean Squared Error:", mean_squared_error(y_reg_test, pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg_test, pred)))
# Out:
# R2_score: 0.924576284122168
# Mean Absolute Error: 0.2586200332326385
# Mean Squared Error: 0.12523677337615644
# Root Mean Squared Error: 0.3538880802968029

# %%
#Save the model for Task(Energy)
import pickle

filename = 'Mcd_Energy.pkl'
pickle.dump(Model, open(filename, 'wb'))

# %%
LoadedModel = pickle.load(open('Mcd_Energy.pkl', 'rb'))
result = LoadedModel.score(X_reg_test, y_reg_test)
print(result * 100)
# Out:
# 92.45762841221679

# %%
Conclusion = pd.DataFrame([LoadedModel.predict(X_reg_test)[:],y_reg_test[:]],index = ["predicted","Original"])
Conclusion
# Out:
#                   0         1         2         3
# predicted  5.812147  9.428975  6.267232  8.730889
# Original   5.938161  8.770667  6.493326  8.754952
