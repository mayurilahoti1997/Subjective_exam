# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\Mohit Lahoti\OneDrive\Desktop\Book2.csv")

# %%
df
# Out:
#    Score out/not out      Against   Inn.  Strick Rate  \
# 0    116         Out     Australia     2        93.85
# 1    103         Out   New Zealand     2       107.37
# 2    103     Not Out       England     2        97.52
# 3    107         Out     Australia     2       100.96
# 4    119         Out  South Africa     1       120.40
# 5    105     Not Out   New Zealand     4       115.05
# 6    115         Out     Australia     2       114.20
# 7    141         Out     Australia     4        95.12
# 8    169         Out     Australia     2       154.65
#
#                          Venue   Column1                       Date Result   \
# 0                Adelaide Oval      Adelaide  24/01/2012               Lost
# 1       M. Chinnaswamy stadium     Bangalore             31/08/2012     Won
# 2  Vidarbha Cricket Associatic        Nagpur             13/12/2012   Drawn
# 3    M. A. chidambaram Stadium       Chennai             22/02/2013     Won
# ...

# %%
df.head()
# Out:
#    Score out/not out      Against   Inn.  Strick Rate  \
# 0    116         Out     Australia     2        93.85
# 1    103         Out   New Zealand     2       107.37
# 2    103     Not Out       England     2        97.52
# 3    107         Out     Australia     2       100.96
# 4    119         Out  South Africa     1       120.40
#
#                          Venue   Column1                       Date Result   \
# 0                Adelaide Oval      Adelaide  24/01/2012               Lost
# 1       M. Chinnaswamy stadium     Bangalore             31/08/2012     Won
# 2  Vidarbha Cricket Associatic        Nagpur             13/12/2012   Drawn
# 3    M. A. chidambaram Stadium       Chennai             22/02/2013     Won
# 4            wanderers Stadium  Johannesburg            18/12/2013,   Drawn
#
#   Format Main of the match Captain
# 0   Test                No      No
# 1   Test               Yes      No
# 2   Test                No      No
# 3    ODI                No      No
# ...

# %%
df.tail()
# Out:
#    Score out/not out      Against   Inn.  Strick Rate  \
# 4    119         Out  South Africa     1       120.40
# 5    105     Not Out   New Zealand     4       115.05
# 6    115         Out     Australia     2       114.20
# 7    141         Out     Australia     4        95.12
# 8    169         Out     Australia     2       154.65
#
#                       Venue   Column1               Date Result  Format  \
# 4         wanderers Stadium  Johannesburg    18/12/2013,   Drawn    ODI
# 5              Basin Reserv    Wellington    14/02/2014,   Drawn   Test
# 6             Adelaide Oval     Adelaide     09/12/2014,    Lost   Test
# 7             Adelaide Oval     Adelaide     09/12/2014,    Lost    ODI
# 8  Melbourne Cricket Ground     Melbourne  26/12/2014      Drawn   Test
#
#   Main of the match Captain
# 4                No      No
# 5                No      No
# 6                No     Yes
# 7                No     Yes
# 8                No      No

# %%
df.shape
# Out:
# (9, 12)

# %%
df.columns
# Out:
# Index(['Score', 'out/not out', 'Against ', 'Inn.', 'Strick Rate', 'Venue',
#        'Column1    ', 'Date', 'Result ', 'Format', 'Main of the match',
#        'Captain'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Score                  int64
# out/not out           object
# Against               object
# Inn.                   int64
# Strick Rate          float64
# Venue                 object
# Column1               object
# Date                  object
# Result                object
# Format                object
# Main of the match     object
# Captain               object
# dtype: object

# %%
#checking the null values
df.isnull().sum()
# Out:
# Score                0
# out/not out          0
# Against              0
# Inn.                 0
# Strick Rate          0
# Venue                0
# Column1              0
# Date                 0
# Result               0
# Format               0
# Main of the match    0
# Captain              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Score              9 non-null      int64
#  1   out/not out        9 non-null      object
#  2   Against            9 non-null      object
#  3   Inn.               9 non-null      int64
#  4   Strick Rate        9 non-null      float64
#  5   Venue              9 non-null      object
#  6   Column1            9 non-null      object
#  7   Date               9 non-null      object
#  8   Result             9 non-null      object
#  9   Format             9 non-null      object
#  10  Main of the match  9 non-null      object
#  11  Captain            9 non-null      object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 992.0+ bytes

# %%
#check null value by using heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#cheking no.of unique values in each column
df.nunique()
# Out:
# Score                8
# out/not out          2
# Against              5
# Inn.                 3
# Strick Rate          9
# Venue                8
# Column1              8
# Date                 8
# Result               3
# Format               2
# Main of the match    2
# Captain              2
# dtype: int64

# %%
# checking the value counts of each column
for col in df.columns:
    print(df[col].value_counts())
    print('\n')
# Out:
# 103    2
# 116    1
# 107    1
# 119    1
# 105    1
# 115    1
# 141    1
# 169    1
# Name: Score, dtype: int64
#
#
# Out        7
# Not Out    2
# Name: out/not out, dtype: int64
#
#
#  Australia      4
# New Zealand     2
# England         1
# Australia       1
# South Africa    1
# Name: Against , dtype: int64
#
#
# 2    6
# 4    2
# 1    1
# Name: Inn., dtype: int64
#
#
# 93.85     1
# 107.37    1
# 97.52     1
# 100.96    1
# 120.40    1
# 115.05    1
# 114.20    1
# 95.12     1
# 154.65    1
# Name: Strick Rate, dtype: int64
#
#
# Adelaide Oval                  2
#  Adelaide Oval                 1
# M. Chinnaswamy stadium         1
# Vidarbha Cricket Associatic    1
# M. A. chidambaram Stadium      1
#  wanderers Stadium             1
#  Basin Reserv                  1
# Melbourne Cricket Ground       1
# Name: Venue, dtype: int64
#
#
# Adelaide        2
# Adelaide        1
# Bangalore       1
# Nagpur          1
# Chennai         1
# Johannesburg    1
#  Wellington     1
# ...

# %%
# Checking for duplicate values
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
# Separate columns by data type
numerical_columns = ['Score', 'Inn.', 'Strick Rate']

# %%
numerical_df = df[numerical_columns]

# %%
description = numerical_df.describe()
description
# Out:
#             Score      Inn.  Strick Rate
# count    9.000000  9.000000     9.000000
# mean   119.777778  2.333333   111.013333
# std     21.953233  1.000000    18.915302
# min    103.000000  1.000000    93.850000
# 25%    105.000000  2.000000    97.520000
# 50%    115.000000  2.000000   107.370000
# 75%    119.000000  2.000000   115.050000
# max    169.000000  4.000000   154.650000

# %%
# Creating a pair plot
sns.pairplot(numerical_df)

# %%
df_outliers = df[numerical_columns]
df_outliers.plot(kind='box', subplots=True, layout=(4,4), fontsize=10, figsize=(12,12))
# Out:
# Score             Axes(0.125,0.712609;0.168478x0.167391)
# Inn.           Axes(0.327174,0.712609;0.168478x0.167391)
# Strick Rate    Axes(0.529348,0.712609;0.168478x0.167391)
# dtype: object

# %%
#remove outliers with z-score method
from scipy.stats import zscore
out_features = df[numerical_columns]
z = np.abs(zscore(out_features))
z
# Out:
#       Score      Inn.  Strick Rate
# 0  0.182522  0.353553     0.962420
# 1  0.810610  0.353553     0.204297
# 2  0.810610  0.353553     0.756628
# 3  0.617352  0.353553     0.563732
# 4  0.037578  1.414214     0.526350
# 5  0.713981  1.767767     0.226353
# 6  0.230836  0.353553     0.178690
# 7  1.025342  1.767767     0.891206
# 8  2.378149  0.353553     2.446891

# %%
#threshold value = 3
np.where (z>3)
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
#data shape after removing outliers
df1 =df[(z<3).all(axis=1)]
df1.shape
# Out:
# (9, 12)

# %%
#shape of old and new data frame
print("old df_",df.shape[0])
print("New df_",df1.shape[0])
# Out:
# old df_ 9
# New df_ 9

# %%
#view data loss by persentage 
print("data loss percentage_",((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# data loss percentage_ 0.0

# %%
df=df1

# %%
# check skewness 
df.skew()
# Out:
# Score          1.730032
# Inn.           1.071429
# Strick Rate    1.696142
# dtype: float64

# %%
#lets check how the data hase been distributed in numerical column
plt.figure(figsize=(10,6), facecolor="white")
plotnumber=1
for col in numerical_columns:
    if plotnumber<=8:
        ax=plt.subplot(4,2,plotnumber)
        sns.distplot(df[col],color="m")
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
        plotnumber+=1
        plt.tight_layout()

# %%
# apply cube root transformation to reduce skewness
for col in numerical_columns:
    if df[col].skew() > 0.5:
        df[col] = np.cbrt(df[col])

# %%
#checking skewness again
df.skew()
# Out:
# Score          1.579649
# Inn.           0.455605
# Strick Rate    1.467786
# dtype: float64

# %%
# Compute the correlation matrix
correlation_matrix = df.corr()

# %%
# Create a heatmap to visualize the correlations
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
# Encode categorical columns using Ordinal Encoder
from sklearn.preprocessing import OrdinalEncoder

OE = OrdinalEncoder()
for i in df.columns:
    if df[i].dtype == 'object':
        df[i] = OE.fit_transform(df[i].values.reshape(-1,1))


df
# Out:
#       Score  out/not out  Against       Inn.  Strick Rate  Venue  Column1      \
# 0  4.876999          1.0       0.0  1.259921     4.544416    0.0          1.0
# 1  4.687548          1.0       3.0  1.259921     4.752925    5.0          3.0
# 2  4.687548          0.0       2.0  1.259921     4.602897    7.0          7.0
# 3  4.747459          1.0       1.0  1.259921     4.656395    4.0          4.0
# 4  4.918685          1.0       4.0  1.000000     4.937899    2.0          5.0
# 5  4.717694          0.0       3.0  1.587401     4.863649    1.0          0.0
# 6  4.862944          1.0       0.0  1.259921     4.851641    3.0          2.0
# 7  5.204828          1.0       0.0  1.587401     4.564823    3.0          2.0
# 8  5.528775          1.0       0.0  1.259921     5.367639    6.0          6.0
#
#    Date  Result   Format  Main of the match  Captain
# 0   5.0      1.0     1.0                0.0      0.0
# 1   7.0      2.0     1.0                1.0      0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 0 to 8
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Score              9 non-null      float64
#  1   out/not out        9 non-null      float64
#  2   Against            9 non-null      float64
#  3   Inn.               9 non-null      float64
#  4   Strick Rate        9 non-null      float64
#  5   Venue              9 non-null      float64
#  6   Column1            9 non-null      float64
#  7   Date               9 non-null      float64
#  8   Result             9 non-null      float64
#  9   Format             9 non-null      float64
#  10  Main of the match  9 non-null      float64
#  11  Captain            9 non-null      float64
# dtypes: float64(12)
# memory usage: 936.0 bytes

# %%
df.describe()
# Out:
#           Score  out/not out  Against       Inn.  Strick Rate     Venue  \
# count  9.000000     9.000000  9.000000  9.000000     9.000000  9.000000
# mean   4.914720     0.777778  1.444444  1.303814     4.793587  3.444444
# std    0.281814     0.440959  1.589899  0.181902     0.257366  2.297341
# min    4.687548     0.000000  0.000000  1.000000     4.544416  0.000000
# 25%    4.717694     1.000000  0.000000  1.259921     4.602897  2.000000
# 50%    4.862944     1.000000  1.000000  1.259921     4.752925  3.000000
# 75%    4.918685     1.000000  3.000000  1.259921     4.863649  5.000000
# max    5.528775     1.000000  4.000000  1.587401     5.367639  7.000000
#
#        Column1          Date   Result     Format  Main of the match   Captain
# count     9.000000  9.000000  9.000000  9.000000           9.000000  9.000000
# mean      3.333333  3.111111  0.777778  0.666667           0.111111  0.222222
# std       2.345208  2.571208  0.833333  0.500000           0.333333  0.440959
# ...

# %%
# check correlation 
cor = df.corr()
cor
# Out:
#                       Score  out/not out  Against       Inn.  Strick Rate  \
# Score              1.000000     0.426695 -0.524024  0.071816     0.611473
# out/not out        0.426695     1.000000 -0.376404 -0.373536     0.132865
# Against           -0.524024    -0.376404  1.000000 -0.271371     0.044867
# Inn.               0.071816    -0.373536 -0.271371  1.000000    -0.238921
# Strick Rate        0.611473     0.132865  0.044867 -0.238921     1.000000
# Venue              0.157378    -0.137102 -0.026618 -0.170682     0.254533
# Column1            0.227400    -0.040291  0.122922 -0.574735     0.325081
# Date               0.108188     0.355247  0.139298 -0.361822     0.330080
# Result            -0.313107     0.529150 -0.199174  0.016680    -0.452035
# Format            -0.112496    -0.377964 -0.104828  0.088125     0.215301
# Main of the match -0.302289     0.188982  0.366900 -0.090488    -0.059247
# Captain            0.239735     0.285714 -0.515079  0.373536    -0.188027
#
# ...

# %%
# Visualizing the correlation by plotting a heatmap
plt.figure(figsize=(20, 15))
sns.heatmap(df.corr(), linewidths=0.1, fmt=".1g", linecolor="black", annot=True, cmap="Blues")
plt.yticks(rotation=0)
plt.show()

# %%
#Separating features and label
x = df.drop("Result", axis=1)
y = df["Result"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 2
#       1 #Separating features and label
# ----> 2 x = df.drop("Result", axis=1)
#       3 y = df["Result"]
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %%
df
# Out:
#       Score  out/not out  Against       Inn.  Strick Rate  Venue  Column1      \
# 0  4.876999          1.0       0.0  1.259921     4.544416    0.0          1.0
# 1  4.687548          1.0       3.0  1.259921     4.752925    5.0          3.0
# 2  4.687548          0.0       2.0  1.259921     4.602897    7.0          7.0
# 3  4.747459          1.0       1.0  1.259921     4.656395    4.0          4.0
# 4  4.918685          1.0       4.0  1.000000     4.937899    2.0          5.0
# 5  4.717694          0.0       3.0  1.587401     4.863649    1.0          0.0
# 6  4.862944          1.0       0.0  1.259921     4.851641    3.0          2.0
# 7  5.204828          1.0       0.0  1.587401     4.564823    3.0          2.0
# 8  5.528775          1.0       0.0  1.259921     5.367639    6.0          6.0
#
#    Date  Result   Format  Main of the match  Captain
# 0   5.0      1.0     1.0                0.0      0.0
# 1   7.0      2.0     1.0                1.0      0.0
# ...

# %%
df.columns
# Out:
# Index(['Score', 'out/not out', 'Against ', 'Inn.', 'Strick Rate', 'Venue',
#        'Column1    ', 'Date', 'Result ', 'Format', 'Main of the match',
#        'Captain'],
#       dtype='object')

# %%
# Separating features and label
x = df.drop("Result ", axis=1)  # Notice the space after "Result"
y = df["Result "]  # Notice the space after "Result"

# %%
#Feature Scalling using standard scalarization
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#       Score  out/not out  Against       Inn.  Strick Rate     Venue  \
# 0 -0.141970     0.534522 -0.963624 -0.255939    -1.026887 -1.590266
# 1 -0.855003     0.534522  1.037749 -0.255939    -0.167576  0.718185
# 2 -0.855003    -1.870829  0.370625 -0.255939    -0.785876  1.641565
# 3 -0.629516     0.534522 -0.296500 -0.255939    -0.565400  0.256495
# 4  0.014922     0.534522  1.704873 -1.771527     0.594739 -0.666886
# 5 -0.741544    -1.870829  1.037749  1.653581     0.288739 -1.128576
# 6 -0.194868     0.534522 -0.963624 -0.255939     0.239255 -0.205196
# 7  1.091874     0.534522 -0.963624  1.653581    -0.942786 -0.205196
# 8  2.311108     0.534522 -0.963624 -0.255939     2.365792  1.179875
#
#    Column1          Date    Format  Main of the match   Captain
# 0    -1.055290  0.779194  0.707107          -0.353553 -0.534522
# 1    -0.150756  1.604222  0.707107           2.828427 -0.534522
# 2     1.658312 -0.870864  0.707107          -0.353553 -0.534522
# ...

# %%
#checking variance inflation factor (vif)
from statsmodels.stats.outliers_influence import variance_inflation_factor

Vif = pd.DataFrame()
Vif['VIF Values'] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
Vif['Features'] = x.columns
Vif
# Out:
#     VIF Values           Features
# 0          inf              Score
# 1          inf        out/not out
# 2          inf           Against
# 3          inf               Inn.
# 4          inf        Strick Rate
# 5          inf              Venue
# 6          inf        Column1
# 7          inf               Date
# 8          inf             Format
# 9          inf  Main of the match
# 10         inf            Captain

# %%
y.value_counts()
# Out:
# 0.0    4
# 1.0    3
# 2.0    2
# Name: Result , dtype: int64

# %% [raw]
# Modelling

# %%
#import liabraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
#Finding the best random state
maxAccu = 0
maxRs = 0

for i in range(1, 200):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=i)
    RFC = RandomForestClassifier()
    RFC.fit(x_train, y_train)
    pred = RFC.predict(x_test)
    acc = accuracy_score(y_test, pred)
    if acc > maxAccu:
        maxAccu = acc
        maxRs = i

print("Best accuracy is", maxAccu, "at random_state", maxRs)
# Out:
# Best accuracy is 1.0 at random_state 20

# %%
#creating train test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=maxRs)

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score
from sklearn.model_selection import cross_val_score

# %%
# Random Forest Classifier
RFC = RandomForestClassifier()
RFC.fit(x_train, y_train)
PredRFC = RFC.predict(x_test)
print(accuracy_score(y_test,PredRFC))
print(confusion_matrix(y_test,PredRFC))
print(classification_report(y_test,PredRFC))
# Out:
# 0.6666666666666666
# [[1 0 1]
#  [0 1 0]
#  [0 0 0]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.50      0.67         2
#          1.0       1.00      1.00      1.00         1
#          2.0       0.00      0.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.67      0.50      0.56         3
# weighted avg       1.00      0.67      0.78         3

# %%
#Extra Trees Classifier
ET = ExtraTreesClassifier()
ET.fit(x_train, y_train)
PredET = ET.predict(x_test)
print(accuracy_score(y_test,PredET))
print(confusion_matrix(y_test,PredET))
print(classification_report(y_test,PredET))
# Out:
# 0.6666666666666666
# [[1 0 1]
#  [0 1 0]
#  [0 0 0]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.50      0.67         2
#          1.0       1.00      1.00      1.00         1
#          2.0       0.00      0.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.67      0.50      0.56         3
# weighted avg       1.00      0.67      0.78         3

# %% [raw]
# CROSS VALIDATION SCORE

# %%
RFC = RandomForestClassifier()
cv_scores = cross_val_score(RFC, x, y, cv=10)  # x and y represent your feature and target variables
print("Cross-validation scores:", cv_scores)
print("Mean accuracy:", cv_scores.mean())
print("Standard deviation:", cv_scores.std())
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:825, in Parallel.dispatch_one_batch(self, iterator)
#     824 try:
# --> 825     tasks = self._ready_batches.get(block=False)
#     826 except queue.Empty:
#     827     # slice the iterator n_jobs * batchsize items at a time. If the
#     828     # slice returns less than that, then the current batchsize puts
#    (...)
#     831     # accordingly to distribute evenly the last items between all
#     832     # workers.
#
# File ~\anaconda3\lib\queue.py:168, in Queue.get(self, block, timeout)
#     167     if not self._qsize():
# --> 168         raise Empty
#     169 elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 2
# ...

# %%
Score = cross_val_score(ET,x,y)
print(Score)
print(Score.mean())
print("Diffrence between Accuracy Score and Cross_Validation_Score is-",accuracy_score(y_test,PredET)- Score.mean())
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:825, in Parallel.dispatch_one_batch(self, iterator)
#     824 try:
# --> 825     tasks = self._ready_batches.get(block=False)
#     826 except queue.Empty:
#     827     # slice the iterator n_jobs * batchsize items at a time. If the
#     828     # slice returns less than that, then the current batchsize puts
#    (...)
#     831     # accordingly to distribute evenly the last items between all
#     832     # workers.
#
# File ~\anaconda3\lib\queue.py:168, in Queue.get(self, block, timeout)
#     167     if not self._qsize():
# --> 168         raise Empty
#     169 elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 1
# ...

# %% [raw]
# HyperparameterTuning

# %%
#ExtraTreesClassifier
from sklearn.model_selection import GridSearchCV

parameters = {
    'criterion': ['gini', 'entropy'],
    'n_estimators': [50, 100, 200, 300],
    'max_depth': [None, 10, 20],
    'n_jobs': [-2, -1, 1],
    'random_state': [10, 50, 1000]
}

# %%
GSV = GridSearchCV(ExtraTreesClassifier(), parameters, cv=5)
GSV.fit(x_train, y_train)
best_params = GSV.best_params_
print("Best Parameters:", best_params)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 2
#       1 GSV = GridSearchCV(ExtraTreesClassifier(), parameters, cv=5)
# ----> 2 GSV.fit(x_train, y_train)
#       3 best_params = GSV.best_params_
#       4 print("Best Parameters:", best_params)
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# ...

# %%
Final_Model = ExtraTreesClassifier(criterion='', max_depth=, n_estimators=, n_jobs=-, random_state=)
Final_Model.fit(x_train, y_train)

pred = Final_Model.predict(x_test)
acc = accuracy_score(y_test, pred)
print("Accuracy:", acc*100)
# Out:
#   Cell In[82], line 1
#     Final_Model = ExtraTreesClassifier(criterion='', max_depth=, n_estimators=, n_jobs=-, random_state=)
#                                                                ^
# SyntaxError: invalid syntax

# %%
#Saving the model using joblib
import joblib
joblib.dump(Final_Model, "virat_kohli_cen.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 3
#       1 #Saving the model using joblib
#       2 import joblib
# ----> 3 joblib.dump(Final_Model, "virat_kohli_cen.pkl")
#
# NameError: name 'Final_Model' is not defined
